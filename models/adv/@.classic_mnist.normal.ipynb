# %% [markdown]
# # Libraries

# %%
# tensorflow utils
import tensorflow as tf

# matplotlib utils
import matplotlib as mpl
import matplotlib.pyplot as plt

# other utils
import pandas as pd
import seaborn as sn

# local config
mpl.rcParams['font.family'] = 'monospace'

# %% [markdown]
# # Datasets

# %%
( (p_images, p_labels),
  (q_images, q_labels), ) = tf.keras.datasets.mnist.load_data()

# normalize
p_images = p_images / 255.0
q_images = q_images / 255.0

# %% [markdown]
# # Model

# %%
model = tf.keras.models.load_model('./classic_mnist.normal.keras')
# Out:
# WARNING:tensorflow:From c:\Users\Kamil\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\backend\tensorflow\core.py:184: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.

# %% [markdown]
# # Test :: Evaluate

# %%
# evaluation
p_eval = model.evaluate(p_images, p_labels)
q_eval = model.evaluate(q_images, q_labels)

# prediction
p_pred = model.predict(p_images).argmax(-1)
q_pred = model.predict(q_images).argmax(-1)

# confusion
p_conf = tf.math.confusion_matrix(p_labels, p_pred)
q_conf = tf.math.confusion_matrix(q_labels, q_pred)
# Out:
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 17s 6ms/step - accuracy: 0.9910 - loss: 0.0305
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.9712 - loss: 0.0942
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step

# %% [markdown]
# # Test :: Visualize

# %%
plt.figure(figsize=(12, 8))

# visualize p confusion matrix
plt.subplot(1, 2, 1)
sn.heatmap(pd.DataFrame(p_conf), annot=True, cbar=False, cmap='gist_gray', fmt='g', square=True).invert_yaxis()
plt.title(f'p accuracy = {p_eval[1]:.2%}')
plt.ylabel('Prediction')
plt.xlabel('True label')

# visualize q confusion matrix
plt.subplot(1, 2, 2)
sn.heatmap(pd.DataFrame(q_conf), annot=True, cbar=False, cmap='gist_gray', fmt='g', square=True).invert_yaxis()
plt.title(f'q accuracy = {q_eval[1]:.2%}')
plt.ylabel('Prediction')
plt.xlabel('True label')

plt.show()
